# %%
import parselmouth
import matplotlib.pyplot as plt
from audiochains.streams import InputStream
from audiochains.block_methods import UnpackRawInFloat32
import numpy as np

# Фильтрация резких скачков частоты
def threshold_filter(data, max_jump=50):
    filtered_data = np.array(data)
    for i in range(1, len(filtered_data)):
        if not np.isnan(filtered_data[i]) and not np.isnan(filtered_data[i - 1]):
            if abs(filtered_data[i] - filtered_data[i - 1]) > max_jump:
                filtered_data[i] = filtered_data[i - 1]
    return filtered_data

# Параметры обработки
METHOD = "ac"
PITCH_FLOOR = 75
PITCH_CEILING = 600
TIME_STEP = 0.01
SILENCE_THRESHOLD_DB = -25.0
VOICING_THRESHOLD = 0.45
OCTAVE_COST = 0.01
OCTAVE_JUMP_COST = 0.35
VOICED_UNVOICED_COST = 0.14
BLOCKSIZE = 1024
MAX_JUMP = 50
BLOCKS_TO_SILENT = 2

# Подготовка графиков
plt.ion()
fig, axes = plt.subplots(3, 1, figsize=(10, 7), sharex=True)

# Фиксированные лимиты осей
axes[0].set_ylim(-50, 0)   # Интенсивность звука (дБ)
axes[1].set_ylim(50, 600)  # Частота (Гц)
axes[2].set_ylim(-0.5, 1.5) # Активность (0 или 1)

plt.show(block=False)

times = []
intensities = []
pitches = []
activity_states = []
current_time = 0
current_state = 0
silent_counter = 0  

# Запуск потока с микрофона
with InputStream(
    samplerate=16000,  
    blocksize=BLOCKSIZE, 
    channels=1,        
    sampwidth=2        
) as stream:
    print(f"Захват звука с микрофона. Частота дискретизации: {stream.samplerate} Гц")
    stream.set_methods(UnpackRawInFloat32())

    for _ in range(stream.get_iterations(seconds=10)):  
        raw_data = stream.read(BLOCKSIZE)
        if not raw_data:
            continue
        

        signal = stream.chain_of_methods(raw_data)  
        sound = parselmouth.Sound(values=signal, sampling_frequency=stream.samplerate)

        # Анализ громкости (интенсивности)
        intensity_obj = sound.to_intensity()
        intensity_values = intensity_obj.values.T.flatten()
        avg_intensity = np.mean(intensity_values) if len(intensity_values) > 0 else -50

        # Анализ pitch
        if METHOD == "ac":
            pitch_obj = sound.to_pitch_ac(
                time_step=TIME_STEP, pitch_floor=PITCH_FLOOR, pitch_ceiling=PITCH_CEILING,
                voicing_threshold=VOICING_THRESHOLD, octave_cost=OCTAVE_COST,
                octave_jump_cost=OCTAVE_JUMP_COST, voiced_unvoiced_cost=VOICED_UNVOICED_COST
            )
        elif METHOD == "cc":
            pitch_obj = sound.to_pitch_cc(
                time_step=TIME_STEP, pitch_floor=PITCH_FLOOR, pitch_ceiling=PITCH_CEILING,
                voicing_threshold=VOICING_THRESHOLD, octave_cost=OCTAVE_COST,
                octave_jump_cost=OCTAVE_JUMP_COST, voiced_unvoiced_cost=VOICED_UNVOICED_COST
            )
        else:
            raise ValueError(f"Неизвестный метод: {METHOD}. Используйте 'ac' или 'cc'.")

        pitch_values = pitch_obj.selected_array['frequency']
        pitch_values[(pitch_values == 0) | (pitch_values > 500)] = np.nan
        avg_pitch = np.nanmean(pitch_values) if np.any(~np.isnan(pitch_values)) else np.nan

        # Определение состояния (Voiced/Silent)
        above_silence_threshold = avg_intensity > SILENCE_THRESHOLD_DB
        valid_pitch = avg_pitch > PITCH_FLOOR

        if above_silence_threshold and valid_pitch:
            current_state = 1
            silent_counter = 0
        else:
            silent_counter += 1
            if silent_counter >= BLOCKS_TO_SILENT:
                current_state = 0

        # Сохранение данных
        times.append(current_time)
        intensities.append(avg_intensity)
        pitches.append(avg_pitch)
        activity_states.append(current_state)

        # Фильтрация выбросов
        filtered_pitches = threshold_filter(pitches, max_jump=MAX_JUMP)

        # Вывод в консоль
        print(f"{current_time:.2f} s - {'Voiced (1)' if current_state else 'Silent (0)'} | "
              f"Intensity: {avg_intensity:.2f} dB | Pitch: {avg_pitch:.2f} Hz")

        # Обновление графиков
        axes[0].cla()
        axes[0].plot(times, intensities, color="blue")
        axes[0].set_ylabel("Интенсивность (дБ)")
        axes[0].set_title("Интенсивность звука")
        axes[0].set_ylim(0, 80)  

        axes[1].cla()
        axes[1].plot(times, filtered_pitches, color="red")
        axes[1].scatter(times, filtered_pitches, color="black", s=5)  
        axes[1].set_ylabel("Частота (Гц)")
        axes[1].set_title("Частота основного тона")
        axes[1].set_ylim(50, 600)  

        axes[2].cla()
        axes[2].step(times, activity_states, color="green", where="post")
        axes[2].set_ylabel("Активность (0 - silent, 1 - voiced)")
        axes[2].set_xlabel("Время (с)")
        axes[2].set_title("Активность речи")
        axes[2].set_ylim(-0.5, 1.5)  

        plt.draw()  # Обновляем график
        plt.pause(0.05)  # Обновляем с задержкой

        current_time += BLOCKSIZE / stream.samplerate
# Out:
# Захват звука с микрофона. Частота дискретизации: 16000.0 Гц
# 0.00 s - Silent (0) | Intensity: 49.23 dB | Pitch: nan Hz
# 0.06 s - Silent (0) | Intensity: 16.10 dB | Pitch: nan Hz
# 0.13 s - Silent (0) | Intensity: 13.19 dB | Pitch: nan Hz
# 0.19 s - Silent (0) | Intensity: 11.69 dB | Pitch: nan Hz
# 0.26 s - Silent (0) | Intensity: 11.00 dB | Pitch: nan Hz
# 0.32 s - Silent (0) | Intensity: 13.12 dB | Pitch: nan Hz
# 0.38 s - Silent (0) | Intensity: 9.81 dB | Pitch: nan Hz
# 0.45 s - Silent (0) | Intensity: 22.12 dB | Pitch: nan Hz
# 0.51 s - Silent (0) | Intensity: 23.67 dB | Pitch: nan Hz
# 0.58 s - Silent (0) | Intensity: 11.37 dB | Pitch: nan Hz
# 0.64 s - Silent (0) | Intensity: 13.10 dB | Pitch: nan Hz
# 0.70 s - Silent (0) | Intensity: 37.65 dB | Pitch: nan Hz
# 0.77 s - Silent (0) | Intensity: 12.58 dB | Pitch: nan Hz
# 0.83 s - Silent (0) | Intensity: 11.32 dB | Pitch: nan Hz
# 0.90 s - Silent (0) | Intensity: 10.45 dB | Pitch: nan Hz
# 0.96 s - Silent (0) | Intensity: 12.00 dB | Pitch: nan Hz
# 1.02 s - Silent (0) | Intensity: 11.93 dB | Pitch: nan Hz
# 1.09 s - Silent (0) | Intensity: 33.94 dB | Pitch: nan Hz
# 1.15 s - Silent (0) | Intensity: 24.95 dB | Pitch: nan Hz
# 1.22 s - Silent (0) | Intensity: 21.63 dB | Pitch: nan Hz
# 1.28 s - Silent (0) | Intensity: 11.56 dB | Pitch: nan Hz
# 1.34 s - Silent (0) | Intensity: 13.70 dB | Pitch: nan Hz
# 1.41 s - Voiced (1) | Intensity: 62.91 dB | Pitch: 140.80 Hz
# 1.47 s - Voiced (1) | Intensity: 66.32 dB | Pitch: 134.80 Hz
# 1.54 s - Voiced (1) | Intensity: 66.03 dB | Pitch: 133.84 Hz
# 1.60 s - Voiced (1) | Intensity: 71.01 dB | Pitch: 194.67 Hz
# 1.66 s - Voiced (1) | Intensity: 71.04 dB | Pitch: 211.41 Hz
# 1.73 s - Voiced (1) | Intensity: 52.82 dB | Pitch: 195.42 Hz
# 1.79 s - Voiced (1) | Intensity: 36.03 dB | Pitch: nan Hz
# 1.86 s - Voiced (1) | Intensity: 58.99 dB | Pitch: 134.64 Hz
# 1.92 s - Voiced (1) | Intensity: 60.08 dB | Pitch: 126.88 Hz
# 1.98 s - Voiced (1) | Intensity: 62.15 dB | Pitch: 127.71 Hz
# 2.05 s - Voiced (1) | Intensity: 64.59 dB | Pitch: 132.94 Hz
# 2.11 s - Voiced (1) | Intensity: 66.66 dB | Pitch: 133.33 Hz
# 2.18 s - Voiced (1) | Intensity: 49.76 dB | Pitch: 132.12 Hz
# 2.24 s - Voiced (1) | Intensity: 40.23 dB | Pitch: nan Hz
# 2.30 s - Voiced (1) | Intensity: 59.61 dB | Pitch: 116.99 Hz
# 2.37 s - Voiced (1) | Intensity: 62.26 dB | Pitch: 118.97 Hz
# 2.43 s - Voiced (1) | Intensity: 58.15 dB | Pitch: 116.44 Hz
# 2.50 s - Voiced (1) | Intensity: 62.03 dB | Pitch: 123.85 Hz
# 2.56 s - Voiced (1) | Intensity: 53.57 dB | Pitch: 122.27 Hz
# 2.62 s - Voiced (1) | Intensity: 34.60 dB | Pitch: 120.89 Hz
# 2.69 s - Voiced (1) | Intensity: 59.85 dB | Pitch: 150.14 Hz
# 2.75 s - Voiced (1) | Intensity: 60.76 dB | Pitch: 159.91 Hz
# 2.82 s - Voiced (1) | Intensity: 61.03 dB | Pitch: 157.41 Hz
# 2.88 s - Voiced (1) | Intensity: 60.14 dB | Pitch: 157.49 Hz
# 2.94 s - Voiced (1) | Intensity: 60.25 dB | Pitch: 157.48 Hz
# 3.01 s - Voiced (1) | Intensity: 61.89 dB | Pitch: 154.81 Hz
# 3.07 s - Voiced (1) | Intensity: 35.08 dB | Pitch: nan Hz
# 3.14 s - Silent (0) | Intensity: 19.45 dB | Pitch: nan Hz
# 3.20 s - Silent (0) | Intensity: 12.21 dB | Pitch: nan Hz
# 3.26 s - Silent (0) | Intensity: 27.95 dB | Pitch: nan Hz
# 3.33 s - Silent (0) | Intensity: 17.08 dB | Pitch: nan Hz
# 3.39 s - Silent (0) | Intensity: 11.74 dB | Pitch: nan Hz
# 3.46 s - Silent (0) | Intensity: 14.28 dB | Pitch: nan Hz
# 3.52 s - Voiced (1) | Intensity: 32.52 dB | Pitch: 489.01 Hz
# 3.58 s - Voiced (1) | Intensity: 22.77 dB | Pitch: nan Hz
# 3.65 s - Silent (0) | Intensity: 18.15 dB | Pitch: nan Hz
# 3.71 s - Silent (0) | Intensity: 14.80 dB | Pitch: nan Hz
# 3.78 s - Silent (0) | Intensity: 10.84 dB | Pitch: nan Hz
# 3.84 s - Silent (0) | Intensity: 11.84 dB | Pitch: nan Hz
# 3.90 s - Silent (0) | Intensity: 19.35 dB | Pitch: nan Hz
# 3.97 s - Voiced (1) | Intensity: 59.29 dB | Pitch: 130.51 Hz
# 4.03 s - Voiced (1) | Intensity: 59.59 dB | Pitch: 134.31 Hz
# 4.10 s - Voiced (1) | Intensity: 60.45 dB | Pitch: 144.00 Hz
# 4.16 s - Voiced (1) | Intensity: 60.09 dB | Pitch: 148.73 Hz
# 4.22 s - Voiced (1) | Intensity: 61.90 dB | Pitch: 165.67 Hz
# 4.29 s - Voiced (1) | Intensity: 67.17 dB | Pitch: 189.31 Hz
# 4.35 s - Voiced (1) | Intensity: 45.59 dB | Pitch: nan Hz
# 4.42 s - Silent (0) | Intensity: 51.65 dB | Pitch: nan Hz
# 4.48 s - Voiced (1) | Intensity: 64.39 dB | Pitch: 123.44 Hz
# 4.54 s - Voiced (1) | Intensity: 47.35 dB | Pitch: nan Hz
# 4.61 s - Silent (0) | Intensity: 54.24 dB | Pitch: nan Hz
# 4.67 s - Voiced (1) | Intensity: 63.50 dB | Pitch: 138.12 Hz
# 4.74 s - Voiced (1) | Intensity: 64.82 dB | Pitch: 139.36 Hz
# 4.80 s - Voiced (1) | Intensity: 59.95 dB | Pitch: 154.46 Hz
# 4.86 s - Voiced (1) | Intensity: 64.57 dB | Pitch: 160.92 Hz
# 4.93 s - Voiced (1) | Intensity: 54.33 dB | Pitch: nan Hz
# 4.99 s - Voiced (1) | Intensity: 61.42 dB | Pitch: 146.05 Hz
# 5.06 s - Voiced (1) | Intensity: 61.94 dB | Pitch: 136.64 Hz
# 5.12 s - Voiced (1) | Intensity: 54.86 dB | Pitch: 132.35 Hz
# 5.18 s - Voiced (1) | Intensity: 27.39 dB | Pitch: nan Hz
# 5.25 s - Silent (0) | Intensity: 20.37 dB | Pitch: nan Hz
# 5.31 s - Silent (0) | Intensity: 11.64 dB | Pitch: nan Hz
# 5.38 s - Silent (0) | Intensity: 29.59 dB | Pitch: nan Hz
# 5.44 s - Silent (0) | Intensity: 12.23 dB | Pitch: nan Hz
# 5.50 s - Silent (0) | Intensity: 10.17 dB | Pitch: nan Hz
# 5.57 s - Silent (0) | Intensity: 27.77 dB | Pitch: nan Hz
# 5.63 s - Silent (0) | Intensity: 22.12 dB | Pitch: nan Hz
# 5.70 s - Silent (0) | Intensity: 20.99 dB | Pitch: nan Hz
# 5.76 s - Silent (0) | Intensity: 30.76 dB | Pitch: nan Hz
# 5.82 s - Silent (0) | Intensity: 19.98 dB | Pitch: nan Hz
# 5.89 s - Silent (0) | Intensity: 20.47 dB | Pitch: nan Hz
# 5.95 s - Silent (0) | Intensity: 36.41 dB | Pitch: nan Hz
# 6.02 s - Silent (0) | Intensity: 19.38 dB | Pitch: nan Hz
# 6.08 s - Voiced (1) | Intensity: 68.89 dB | Pitch: 175.51 Hz
# 6.14 s - Voiced (1) | Intensity: 58.42 dB | Pitch: 186.04 Hz
# 6.21 s - Voiced (1) | Intensity: 60.87 dB | Pitch: 169.73 Hz
# 6.27 s - Voiced (1) | Intensity: 64.86 dB | Pitch: 192.38 Hz
# 6.34 s - Voiced (1) | Intensity: 70.42 dB | Pitch: 185.88 Hz
# 6.40 s - Voiced (1) | Intensity: 70.78 dB | Pitch: 187.93 Hz
# 6.46 s - Voiced (1) | Intensity: 70.64 dB | Pitch: 187.45 Hz
# 6.53 s - Voiced (1) | Intensity: 68.09 dB | Pitch: 168.89 Hz
# 6.59 s - Voiced (1) | Intensity: 67.27 dB | Pitch: 169.01 Hz
# 6.66 s - Voiced (1) | Intensity: 44.32 dB | Pitch: 165.17 Hz
# 6.72 s - Voiced (1) | Intensity: 50.69 dB | Pitch: nan Hz
# 6.78 s - Voiced (1) | Intensity: 64.66 dB | Pitch: 160.90 Hz
# 6.85 s - Voiced (1) | Intensity: 64.79 dB | Pitch: 163.21 Hz
# 6.91 s - Voiced (1) | Intensity: 65.38 dB | Pitch: 161.71 Hz
# 6.98 s - Voiced (1) | Intensity: 62.96 dB | Pitch: 164.27 Hz
# 7.04 s - Voiced (1) | Intensity: 41.71 dB | Pitch: nan Hz
# 7.10 s - Silent (0) | Intensity: 40.22 dB | Pitch: nan Hz
# 7.17 s - Voiced (1) | Intensity: 65.08 dB | Pitch: 155.49 Hz
# 7.23 s - Voiced (1) | Intensity: 65.28 dB | Pitch: 156.43 Hz
# 7.30 s - Voiced (1) | Intensity: 64.72 dB | Pitch: 153.38 Hz
# 7.36 s - Voiced (1) | Intensity: 64.17 dB | Pitch: 142.29 Hz
# 7.42 s - Voiced (1) | Intensity: 62.29 dB | Pitch: 146.70 Hz
# 7.49 s - Voiced (1) | Intensity: 44.10 dB | Pitch: 138.27 Hz
# 7.55 s - Voiced (1) | Intensity: 37.13 dB | Pitch: nan Hz
# 7.62 s - Silent (0) | Intensity: 58.76 dB | Pitch: nan Hz
# 7.68 s - Voiced (1) | Intensity: 62.71 dB | Pitch: 140.63 Hz
# 7.74 s - Voiced (1) | Intensity: 62.73 dB | Pitch: 140.67 Hz
# 7.81 s - Voiced (1) | Intensity: 59.38 dB | Pitch: 142.60 Hz
# 7.87 s - Voiced (1) | Intensity: 45.37 dB | Pitch: nan Hz
# 7.94 s - Voiced (1) | Intensity: 37.07 dB | Pitch: 153.03 Hz
# 8.00 s - Voiced (1) | Intensity: 61.11 dB | Pitch: 141.80 Hz
# 8.06 s - Voiced (1) | Intensity: 61.33 dB | Pitch: 147.08 Hz
# 8.13 s - Voiced (1) | Intensity: 62.58 dB | Pitch: 144.98 Hz
# 8.19 s - Voiced (1) | Intensity: 51.11 dB | Pitch: 138.94 Hz
# 8.26 s - Voiced (1) | Intensity: 63.26 dB | Pitch: 131.93 Hz
# 8.32 s - Voiced (1) | Intensity: 52.47 dB | Pitch: 129.30 Hz
# 8.38 s - Voiced (1) | Intensity: 31.77 dB | Pitch: 131.92 Hz
# 8.45 s - Voiced (1) | Intensity: 12.41 dB | Pitch: nan Hz
# 8.51 s - Silent (0) | Intensity: 11.37 dB | Pitch: nan Hz
# 8.58 s - Silent (0) | Intensity: 24.63 dB | Pitch: nan Hz
# 8.64 s - Silent (0) | Intensity: 24.95 dB | Pitch: nan Hz
# 8.70 s - Silent (0) | Intensity: 14.23 dB | Pitch: nan Hz
# 8.77 s - Silent (0) | Intensity: 15.11 dB | Pitch: nan Hz
# 8.83 s - Silent (0) | Intensity: 12.42 dB | Pitch: nan Hz
# 8.90 s - Silent (0) | Intensity: 12.45 dB | Pitch: nan Hz
# 8.96 s - Voiced (1) | Intensity: 35.90 dB | Pitch: 178.87 Hz
# 9.02 s - Voiced (1) | Intensity: 25.27 dB | Pitch: nan Hz
# 9.09 s - Silent (0) | Intensity: 39.55 dB | Pitch: nan Hz
# 9.15 s - Voiced (1) | Intensity: 64.18 dB | Pitch: 156.10 Hz
# 9.22 s - Voiced (1) | Intensity: 60.30 dB | Pitch: 150.09 Hz
# 9.28 s - Voiced (1) | Intensity: 47.71 dB | Pitch: nan Hz
# 9.34 s - Voiced (1) | Intensity: 57.19 dB | Pitch: 145.46 Hz
# 9.41 s - Voiced (1) | Intensity: 59.23 dB | Pitch: 122.88 Hz
# 9.47 s - Voiced (1) | Intensity: 25.12 dB | Pitch: nan Hz
# 9.54 s - Silent (0) | Intensity: 18.19 dB | Pitch: nan Hz
# 9.60 s - Silent (0) | Intensity: 12.76 dB | Pitch: nan Hz
# 9.66 s - Silent (0) | Intensity: 13.50 dB | Pitch: nan Hz
# 9.73 s - Silent (0) | Intensity: 11.67 dB | Pitch: nan Hz
# 9.79 s - Silent (0) | Intensity: 11.06 dB | Pitch: nan Hz
# 9.86 s - Silent (0) | Intensity: 12.97 dB | Pitch: nan Hz
# 9.92 s - Silent (0) | Intensity: 11.04 dB | Pitch: nan Hz
